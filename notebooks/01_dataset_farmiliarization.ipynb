# %%
zip_path = "/content/drive/MyDrive/AirBnB Project.zip"

# %%
# !unzip -q "/content/drive/MyDrive/AirBnB Project.zip" -d "/content/data"

# %%
import pandas as pd

# %% [markdown]
# # Listings Data

# %%
df_listings_data = pd.read_csv("/content/data/AirBnB Project/listingsdata.csv")

df_listings_data.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  13913  https://www.airbnb.com/rooms/13913  20250914034649   2025-09-16
# 1  15400  https://www.airbnb.com/rooms/15400  20250914034649   2025-09-16
# 2  17402  https://www.airbnb.com/rooms/17402  20250914034649   2025-09-16
# 3  24328  https://www.airbnb.com/rooms/24328  20250914034649   2025-09-18
# 4  36274  https://www.airbnb.com/rooms/36274  20250914034649   2025-09-15
#
#             source                                               name  \
# 0      city scrape                Holiday London DB Room Let-on going
# 1      city scrape                Bright Chelsea  Apartment. Chelsea!
# 2      city scrape   Very Central Modern 3-Bed/2 Bath By Oxford St W1
# 3  previous scrape                   Battersea live/work artist house
# 4      city scrape  Bright 1 bedroom apt off brick lane in Shoreditch
#
#                                          description  \
# ...

# %%
df_listings_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96871 entries, 0 to 96870
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            96871 non-null  int64
#  1   listing_url                                   96871 non-null  object
#  2   scrape_id                                     96871 non-null  int64
#  3   last_scraped                                  96871 non-null  object
#  4   source                                        96871 non-null  object
#  5   name                                          96871 non-null  object
#  6   description                                   94421 non-null  object
#  7   neighborhood_overview                         41208 non-null  object
#  8   picture_url                                   96865 non-null  object
# ...

# %%
df_listings_data.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
# ...

# %%
df_listings_data.describe()
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  9.687100e+04  9.687100e+04  9.687100e+04         96830.000000
# mean   6.894448e+17  2.025091e+13  2.144494e+08            50.088991
# std    5.941222e+17  2.460560e+01  2.196053e+08           399.405694
# min    1.391300e+04  2.025091e+13  2.594000e+03             1.000000
# 25%    3.026058e+07  2.025091e+13  2.726814e+07             1.000000
# 50%    8.505248e+17  2.025091e+13  1.164321e+08             2.000000
# 75%    1.254262e+18  2.025091e+13  4.198974e+08            10.000000
# max    1.508964e+18  2.025091e+13  7.186905e+08          5469.000000
#
#        host_total_listings_count  neighbourhood_group_cleansed      latitude  \
# count               96830.000000                           0.0  96871.000000
# mean                   80.305246                           NaN     51.509740
# std                   589.326173                           NaN      0.049067
# ...

# %%
missing_pct = df_listings_data.isnull().mean() * 100
missing_pct = missing_pct[missing_pct > 0]

print(missing_pct.to_string())
# Out:
# description                       2.529137
# neighborhood_overview            57.460953
# picture_url                       0.006194
# host_name                         0.044389
# host_since                        0.042324
# host_location                    24.538820
# host_about                       48.557360
# host_response_time               32.731158
# host_response_rate               32.731158
# host_acceptance_rate             28.656667
# host_is_superhost                 1.823043
# host_thumbnail_url                0.042324
# host_picture_url                  0.042324
# host_neighbourhood               52.669013
# host_listings_count               0.042324
# host_total_listings_count         0.042324
# host_verifications                0.042324
# host_has_profile_pic              0.042324
# host_identity_verified            0.042324
# neighbourhood                    57.459921
# neighbourhood_group_cleansed    100.000000
# bathrooms                        35.971550
# ...

# %% [markdown]
# # Calender

# %%
df_calender = pd.read_csv("/content/data/AirBnB Project/calendar.csv")

df_calender.head()
# Out:
#             listing_id        date available  price  adjusted_price  \
# 0  1196288722069341420  2025-09-15         f    NaN             NaN
# 1  1196288722069341420  2025-09-16         f    NaN             NaN
# 2  1196288722069341420  2025-09-17         f    NaN             NaN
# 3  1196288722069341420  2025-09-18         f    NaN             NaN
# 4  1196288722069341420  2025-09-19         f    NaN             NaN
#
#    minimum_nights  maximum_nights
# 0               1            1125
# 1               1            1125
# 2               1            1125
# 3               1            1125
# 4               1            1125

# %%
df_calender.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35357974 entries, 0 to 35357973
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            object
#  2   available       object
#  3   price           float64
#  4   adjusted_price  float64
#  5   minimum_nights  int64
#  6   maximum_nights  int64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 1.8+ GB

# %%
df_calender.columns
# Out:
# Index(['listing_id', 'date', 'available', 'price', 'adjusted_price',
#        'minimum_nights', 'maximum_nights'],
#       dtype='object')

# %%
df_calender.describe()
# Out:
#          listing_id  price  adjusted_price  minimum_nights  maximum_nights
# count  3.535797e+07    0.0             0.0    3.535797e+07    3.535797e+07
# mean   6.894452e+17    NaN             NaN    6.263561e+00    2.921079e+05
# std    5.941191e+17    NaN             NaN    2.442387e+01    2.483581e+07
# min    1.391300e+04    NaN             NaN    1.000000e+00    1.000000e+00
# 25%    3.026024e+07    NaN             NaN    1.000000e+00    9.000000e+01
# 50%    8.505248e+17    NaN             NaN    2.000000e+00    3.650000e+02
# 75%    1.254268e+18    NaN             NaN    4.000000e+00    1.125000e+03
# max    1.508964e+18    NaN             NaN    1.125000e+03    2.147484e+09

# %%
missing_pct1 = df_calender.isnull().mean() * 100
missing_pct1 = missing_pct1[missing_pct1 > 0]

print(missing_pct1.to_string())
# Out:
# price             100.0
# adjusted_price    100.0

# %% [markdown]
# # Reviews Data

# %%
df_reviews_data = pd.read_csv("/content/data/AirBnB Project/reviewsdata.csv")

df_reviews_data.head()
# Out:
#    listing_id      id        date  reviewer_id reviewer_name  \
# 0       13913   80770  2010-08-18       177109       Michael
# 1       13913  367568  2011-07-11     19835707       Mathias
# 2       13913  529579  2011-09-13      1110304       Kristin
# 3       13913  595481  2011-10-03      1216358       Camilla
# 4       13913  612947  2011-10-09       490840         Jorik
#
#                                             comments
# 0  My girlfriend and I hadn't known Alina before ...
# 1  Alina was a really good host. The flat is clea...
# 2  Alina is an amazing host. She made me feel rig...
# 3  Alina's place is so nice, the room is big and ...
# 4  Nice location in Islington area, good for shor...

# %%
df_reviews_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2097996 entries, 0 to 2097995
# Data columns (total 6 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   listing_id     int64
#  1   id             int64
#  2   date           object
#  3   reviewer_id    int64
#  4   reviewer_name  object
#  5   comments       object
# dtypes: int64(3), object(3)
# memory usage: 96.0+ MB

# %%
df_reviews_data.columns
# Out:
# Index(['listing_id', 'id', 'date', 'reviewer_id', 'reviewer_name', 'comments'], dtype='object')

# %%
df_reviews_data.describe()
# Out:
#          listing_id            id   reviewer_id
# count  2.097996e+06  2.097996e+06  2.097996e+06
# mean   3.572207e+17  7.776855e+17  1.968301e+08
# std    4.905399e+17  5.533266e+17  1.875552e+08
# min    1.391300e+04  2.103200e+04  4.400000e+01
# 25%    1.581313e+07  5.707448e+08  4.043916e+07
# 50%    3.798997e+07  9.259551e+17  1.279123e+08
# 75%    8.332622e+17  1.261510e+18  3.257543e+08
# max    1.508900e+18  1.512348e+18  7.188301e+08

# %%
missing_pct2 = df_reviews_data.isnull().mean() * 100
missing_pct2 = missing_pct2[missing_pct2 > 0]

print(missing_pct2.to_string())
# Out:
# reviewer_name    0.000095
# comments         0.009581

# %% [markdown]
# # Listings Info

# %%
df_listings_info = pd.read_csv("/content/data/AirBnB Project/listings.csv")

df_listings_info.head()
# Out:
#       id                                               name  host_id  \
# 0  13913                Holiday London DB Room Let-on going    54730
# 1  15400                Bright Chelsea  Apartment. Chelsea!    60302
# 2  17402   Very Central Modern 3-Bed/2 Bath By Oxford St W1    67564
# 3  24328                   Battersea live/work artist house    41759
# 4  36274  Bright 1 bedroom apt off brick lane in Shoreditch   133271
#
#   host_name  neighbourhood_group           neighbourhood  latitude  longitude  \
# 0     Alina                  NaN               Islington  51.56861   -0.11270
# 1  Philippa                  NaN  Kensington and Chelsea  51.48780   -0.16813
# 2       Liz                  NaN             Westminster  51.52195   -0.14094
# 3       Joe                  NaN              Wandsworth  51.47072   -0.16266
# 4  Hendryks                  NaN           Tower Hamlets  51.52322   -0.06979
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df_listings_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96871 entries, 0 to 96870
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              96871 non-null  int64
#  1   name                            96871 non-null  object
#  2   host_id                         96871 non-null  int64
#  3   host_name                       96828 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   96871 non-null  object
#  6   latitude                        96871 non-null  float64
#  7   longitude                       96871 non-null  float64
#  8   room_type                       96871 non-null  object
#  9   price                           61963 non-null  float64
#  10  minimum_nights                  96871 non-null  int64
#  11  number_of_reviews               96871 non-null  int64
# ...

# %%
df_listings_info.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
df_listings_info.describe()
# Out:
#                  id       host_id  neighbourhood_group      latitude  \
# count  9.687100e+04  9.687100e+04                  0.0  96871.000000
# mean   6.894448e+17  2.144494e+08                  NaN     51.509740
# std    5.941222e+17  2.196053e+08                  NaN      0.049067
# min    1.391300e+04  2.594000e+03                  NaN     51.295937
# 25%    3.026058e+07  2.726814e+07                  NaN     51.484150
# 50%    8.505248e+17  1.164321e+08                  NaN     51.513720
# 75%    1.254262e+18  4.198974e+08                  NaN     51.539108
# max    1.508964e+18  7.186905e+08                  NaN     51.682630
#
#           longitude         price  minimum_nights  number_of_reviews  \
# count  96871.000000  6.196300e+04    96871.000000       96871.000000
# mean      -0.127638  2.299170e+02        5.440297          21.657627
# std        0.101112  4.437589e+03       23.686681          50.368644
# ...

# %%
missing_pct3 = df_listings_info.isnull().mean() * 100
missing_pct3 = missing_pct3[missing_pct3 > 0]

print(missing_pct3.to_string())
# Out:
# host_name                0.044389
# neighbourhood_group    100.000000
# price                   36.035552
# last_review             24.901157
# reviews_per_month       24.901157
# license                100.000000

# %% [markdown]
# ## Reviews Info

# %%
df_reviews_info = pd.read_csv("/content/data/AirBnB Project/reviews.csv")

df_reviews_info.head()
# Out:
#    listing_id        date
# 0       13913  2010-08-18
# 1       13913  2011-07-11
# 2       13913  2011-09-13
# 3       13913  2011-10-03
# 4       13913  2011-10-09

# %%
df_reviews_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2097996 entries, 0 to 2097995
# Data columns (total 2 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   listing_id  int64
#  1   date        object
# dtypes: int64(1), object(1)
# memory usage: 32.0+ MB

# %%
df_reviews_info.columns
# Out:
# Index(['listing_id', 'date'], dtype='object')

# %%
(df_reviews_info.isnull().sum()/len(df_reviews_info))*100
# Out:
# listing_id    0.0
# date          0.0
# dtype: float64

# %% [markdown]
# # Neighbourhoods

# %%
df_neighbourhoods = pd.read_csv("/content/data/AirBnB Project/neighbourhoods.csv")

df_neighbourhoods.head()
# Out:
#    neighbourhood_group         neighbourhood
# 0                  NaN  Barking and Dagenham
# 1                  NaN                Barnet
# 2                  NaN                Bexley
# 3                  NaN                 Brent
# 4                  NaN               Bromley

# %%
df_neighbourhoods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   neighbourhood_group  0 non-null      float64
#  1   neighbourhood        33 non-null     object
# dtypes: float64(1), object(1)
# memory usage: 660.0+ bytes

# %%
df_neighbourhoods.columns
# Out:
# Index(['neighbourhood_group', 'neighbourhood'], dtype='object')

# %%
(df_neighbourhoods.isnull().sum()/len(df_neighbourhoods))*100
# Out:
# neighbourhood_group    100.0
# neighbourhood            0.0
# dtype: float64
